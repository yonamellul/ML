# %%
import data
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pickle
#import pandas as pd
from src.tme2 import *

# %%
POI_FILENAME = "data/poi-paris.pkl"
parismap = mpimg.imread('data/paris-48.806-2.23--48.916-2.48.jpg')
show_img()

# %%
monHisto = Histogramme()
geo_mat, notes = load_poi("night_club")
monHisto.fit(geo_mat)
show_density(monHisto, geo_mat, steps = 10)
density = get_density2D(monHisto, geo_mat, 10)
print("density == 1?", sum(density[0] == 1 )
print(density)
# Out:
# density == 1? False
# (array([[   0.        ,   38.82197552,   77.64395104,    0.        ,
#           38.82197552,   77.64395104,   77.64395104,  116.46592656,
#            0.        ,   77.64395104],
#        [   0.        ,  116.46592656,   38.82197552,   77.64395104,
#           38.82197552,   77.64395104,   77.64395104,   77.64395104,
#            0.        ,    0.        ],
#        [  38.82197552,   77.64395104,   77.64395104,  349.39777969,
#          116.46592656,  310.57580417,  194.10987761,   77.64395104,
#            0.        ,    0.        ],
#        [ 155.28790209,   38.82197552,  232.93185313,  504.68568178,
#          427.04173074,  621.15160834,  194.10987761,   38.82197552,
#            0.        ,    0.        ],
#        [  38.82197552,   38.82197552,  116.46592656,   77.64395104,
#         1785.81087399, 1242.30321669,  116.46592656,   38.82197552,
#          116.46592656,    0.        ],
#        [   0.        ,   38.82197552,  504.68568178, 1242.30321669,
# ...

# %%
monHisto = Histogramme()
geo_mat, notes = load_poi("restaurant")
monHisto.fit(geo_mat)
show_density(monHisto, geo_mat, steps = 10)
